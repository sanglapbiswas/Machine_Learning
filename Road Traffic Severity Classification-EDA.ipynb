# %%
###################### Install packages for dabl ###########################
#!conda install git
#!pip install threadpoolctl==3.1.0
#!pip install git+https://github.com/amueller/dabl/
# !pip install dabl
# !pip install scikit-learn==1.1.1
# !pip install matplotlib --user
#!pip show matplotlib
#!pip install dabl -- user
#import dabl
import dabl

# %%
import pandas as pd
import matplotlib.pyplot as plt
#from mpl_toolkits.mplot3d import Axes3D
import matplotlib as mpl
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
########################### Import Dataset ################################
import pandas as pd
df = pd.read_csv(r'D:\Machine Learning\W1\RTA Dataset.csv')
#print(df)

# %%
import dabl
#import sys
#print("User Current Version:-",sys.version)

# %%
##### ####Xxplore data set & variables #######
df.head(15)
dabl.detect_types(df)
# Out:
#                              continuous  dirty_float  low_card_int  \
# Time                              False        False         False
# Day_of_week                       False        False         False
# Age_band_of_driver                False        False         False
# Sex_of_driver                     False        False         False
# Educational_level                 False        False         False
# Vehicle_driver_relation           False        False         False
# Driving_experience                False        False         False
# Type_of_vehicle                   False        False         False
# Owner_of_vehicle                  False        False         False
# Service_year_of_vehicle           False        False         False
# Defect_of_vehicle                 False        False         False
# Area_accident_occured             False        False         False
# Lanes_or_Medians                  False        False         False
# ...

# %%
dabl.plot(df, target_col="Accident_severity")
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Target looks like classification
# Showing only top 10 of 32 categorical features
# C:\Users\user\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\user\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\user\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# ...

# %%
##################################### EDA USING AUTOVIZ ###############################

# %%
#importing Autoviz class
# !pip install bokeh --user
# !pip install autoviz
from autoviz.AutoViz_Class import AutoViz_Class#Instantiate the AutoViz class
AV = AutoViz_Class()
# Out:
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-fc8d3446b9ad> in <module>
#       2 get_ipython().system('pip install bokeh --user')
#       3 get_ipython().system('pip install autoviz')
# ----> 4 from autoviz.AutoViz_Class import AutoViz_Class#Instantiate the AutoViz class
#       5 AV = AutoViz_Class()
#
# ~\anaconda3\lib\site-packages\autoviz\__init__.py in <module>
#       1 name = "autoviz"
#       2 from .__version__ import __version__, __holo_version__
# ----> 3 from .AutoViz_Class import AutoViz_Class
#       4 from .classify_method import data_cleaning_suggestions
#       5 if __name__ == "__main__":
#
# ~\anaconda3\lib\site-packages\autoviz\AutoViz_Class.py in <module>
#      59 from sklearn.model_selection import train_test_split
#      60 ##########################################################################################
# ...

# %%
#importing Autoviz class
from autoviz.AutoViz_Class import AutoViz_Class#Instantiate the AutoViz class
AV = AutoViz_Class()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-40987f355a01> in <module>
#       1 #importing Autoviz class
# ----> 2 from autoviz.AutoViz_Class import AutoViz_Class#Instantiate the AutoViz class
#       3 AV = AutoViz_Class()
#
# ~\anaconda3\lib\site-packages\autoviz\__init__.py in <module>
#       1 name = "autoviz"
#       2 from .__version__ import __version__, __holo_version__
# ----> 3 from .AutoViz_Class import AutoViz_Class
#       4 from .classify_method import data_cleaning_suggestions
#       5 if __name__ == "__main__":
#
# ~\anaconda3\lib\site-packages\autoviz\AutoViz_Class.py in <module>
#      59 from sklearn.model_selection import train_test_split
#      60 ##########################################################################################
# ---> 61 from autoviz.AutoViz_Holo import AutoViz_Holo
# ...
